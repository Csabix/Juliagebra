# %%
using Juliagebra
# Out:
# [ Info: Precompiling Juliagebra [00df127a-38ce-4188-9178-c0c128ce8b4d] (cache misses: include_dependency fsize change (2), wrong dep version loaded (2))
#
# SYSTEM: caught exception of type :MethodError while trying to print a failed Task notice; giving up

# %%
Juliagebra.Empty()
# Out:
# Juliagebra.EmptySceneCommand()

# %%
cursor = Point(0,0,5)
# Out:
# Juliagebra.PointDependent(Juliagebra.RenderedDependent(Juliagebra.Subject(Juliagebra.Dependent(4, Juliagebra.DependentDNA[], Any[], Juliagebra.DependentChain(Juliagebra.DependentDNA[], Set(Juliagebra.ObserverDNA[Juliagebra.PointRenderer(Juliagebra.Renderer{Juliagebra.PointDependent}(Juliagebra.Observer{Juliagebra.PointDependent}(Juliagebra.PointDependent[Juliagebra.PointDependent(#= circular reference @-10 =#)], true), Juliagebra.OpenGLData(Juliagebra.SharedData("Juliagebra", 960, 1011, false, 0x00000000, false, 0, 0, 1, 746, 0.0, false, 1.774305243419081e9, 0.0060679913f0, 0x00000000, 0x00000000, false), Juliagebra.OpenGLWidgetDNA[Juliagebra.GizmoGL(Juliagebra.OpenGLWidget(Juliagebra.Widget(false)), Juliagebra.ShaderProgram(0x00000004, Dict{String, Int32}("gizmoCenter" => 3, "nanVal" => 5, "gizmoScale" => 4, "VP" => 0, "selectedID" => 6, "WH" => 1)), JuliaGLM.Vec3T{Float32}[Vec3(1.0,0.0,0.0), Vec3(0.0,1.0,0.0), Vec3(0.0,0.0,1.0)], Vec3(-3.85926,-1.69309,13.2147), 0.085f0), Juliagebra.OrthoGizmoGL(Juliagebra.OpenGLWidget(Juliagebra.Widget(false)), Juliagebra.ShaderProgram(0x00000008, Dict{String, Int32}("VP" => 0, "WH" => 1)))], Juliagebra.RendererDNA[Juliagebra.SphereRenderer(Juliagebra.Renderer{Juliagebra.SphereDependent}(Juliagebra.Observer{Juliagebra.SphereDependent}(Juliagebra.SphereDependent[], false), Juliagebra.OpenGLData(#= circular reference @-4 =#)), Juliagebra.ShaderProgram(0x00000015, Dict{String, Int32}("ASPECT_FOV_RESOLUTION" => 0, "VP" => 1, "at" => 2, "cam" => 3)), Juliagebra.ShaderProgram(0x00000019, Dict{String, Int32}("ASPECT_FOV_RESOLUTION" => 0, "VP" => 1, "at" => 2, "lightDirSide" => 5, "cam" => 3, "lightDirCam" => 4)), Juliagebra.ShaderProgram(0x0000001d, Dict{String, Int32}("ASPECT_FOV_RESOLUTION" => 0, "VP" => 1, "at" => 2, "lightDirSide" => 5, "cam" => 3, "lightDirCam" => 4)), Juliagebra.BufferArray{Tuple{Juliagebra.MappedBuffer{JuliaGLM.Vec3T{Float32}}, Juliagebra.MappedBuffer{Float32}, Juliagebra.Buffer{JuliaGLM.Vec3T{Float32}}}}((Juliagebra.MappedBuffer{JuliaGLM.Vec3T{Float32}}(0x00000003, 0, JuliaGLM.Vec3T{Float32}[], Ptr{Nothing}(0x0000000000000000)), Juliagebra.MappedBuffer{Float32}(0x00000004, 0, Float32[], Ptr{Nothing}(0x0000000000000000)), Juliagebra.Buffer{JuliaGLM.Vec3T{Float32}}(0x00000005, 0)), Juliagebra.VertexArray(0x00000003)), Juliagebra.BufferArray{Tuple{Juliagebra.MappedBuffer{JuliaGLM.Vec3T{Float32}}, Juliagebra.MappedBuffer{Float32}, Juliagebra.Buffer{JuliaGLM.Vec3T{Float32}}}}((Juliagebra.MappedBuffer{JuliaGLM.Vec3T{Float32}}(0x00000006, 0, JuliaGLM.Vec3T{Float32}[], Ptr{Nothing}(0x0000000000000000)), Juliagebra.MappedBuffer{Float32}(0x00000007, 0, Float32[], Ptr{Nothing}(0x0000000000000000)), Juliagebra.Buffer{JuliaGLM.Vec3T{Float32}}(0x00000008, 0)), Juliagebra.VertexArray(0x00000004)), JuliaGLM.Vec3T{Float32}[], Float32[], JuliaGLM.Vec3T{Float32}[], JuliaGLM.Vec3T{Float32}[], Float32[], JuliaGLM.Vec3T{Float32}[]), Juliagebra.ParametricSurfaceRenderer(Juliagebra.Renderer{Juliagebra.ParametricSurfaceDependent}(Juliagebra.Observer{Juliagebra.ParametricSurfaceDependent}(Juliagebra.ParametricSurfaceDependent[], false), Juliagebra.OpenGLData(#= circular reference @-4 =#)), Juliagebra.ShaderProgram(0x00000020, Dict{String, Int32}("VP" => 0)), Juliagebra.ShaderProgram(0x00000023, Dict{String, Int32}("VP" => 0, "lightDirSide" => 2, "lightDirCam" => 1)), Juliagebra.ShaderProgram(0x00000026, Dict{String, Int32}("VP" => 0, "lightDirSide" => 2, "lightDirCam" => 1)), Juliagebra.IndexedBufferArray{Tuple{JuliaGLM.Vec3T{Float32}, JuliaGLM.Vec3T{Float32}, JuliaGLM.Vec3T{Float32}}}(Juliagebra.BufferArray{Tuple{Juliagebra.MappedBuffer{JuliaGLM.Vec3T{Float32}}, Juliagebra.MappedBuffer{JuliaGLM.Vec3T{Float32}}, Juliagebra.Buffer{JuliaGLM.Vec3T{Float32}}}}((Juliagebra.MappedBuffer{JuliaGLM.Vec3T{Float32}}(0x00000009, 0, JuliaGLM.Vec3T{Float32}[], Ptr{Nothing}(0x0000000000000000)), Juliagebra.MappedBuffer{JuliaGLM.Vec3T{Float32}}(0x0000000a, 0, JuliaGLM.Vec3T{Float32}[], Ptr{Nothing}(0x0000000000000 ...

# %%
function wave(xf,yf,zf,cap,xc,yc,zc)
    distance = sqrt((xc - xf)^2 + (yc - yf)^2)/ cap * 0.2

    if distance > 1
        distance = 1
    end

    z = zc + (zf - zc) * distance
    return (xf,yf,z)
end

for x in -10:10
    for y in -10:10
        cap = 3.0
        xf = x * cap
        yf = y * cap
        Point([cursor]) do cur
            return wave(xf,yf,0.0,cap,cur.x,cur.y,cur.z)
        end
    end
end
# Out:
# ThreadID(10): Builder Ended!
# ThreadID(1): App Ended!
